# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import cv2
import os

import csv
import json

import tensorflow as tf

from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

from keras.models import Sequential,load_model,Model
from keras.layers import Conv2D,MaxPooling2D,AvgPool2D,GlobalAveragePooling2D,Dense,Dropout,BatchNormalization,Flatten,Input
from sklearn.model_selection import train_test_split


from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# !unzip val.zip
# Out:
# Archive:  val.zip
#    creating: val/
#   inflating: val/httpabsolumentgratuitfreefrimagesbenaffleckjpg.jpg
#   inflating: val/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTENDgMDUODczNDcNTcjpg.jpg
#   inflating: val/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTEODAOTcxNjcMjczMjkzjpg.jpg
#   inflating: val/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTIOTcwODQNTUzNjQMzcjpg.jpg
#   inflating: val/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTIwNjANjMMDINzIxNjcjpg.jpg
#   inflating: val/httpassetsrollingstonecomassetsarticlemadonnadavidbowiechangedthecourseofmylifeforeversmallsquarexmadonnabowiejpg.jpg
#   inflating: val/httpassetsrollingstonecomassetsimagesalbumreviewaffaceabdcccaeedjpg.jpg
#   inflating: val/httpaurorasblogcomwpcontentuploadsjerryseinfeldpublicityshotjpg.jpg
#   inflating: val/httpblognjcomentertainmentimpactcelebritiesmediumjerrybjpg.jpg
#   inflating: val/httpbpblogspotcomedLMjVpRGkSWexgsXjkNIAAAAAAAADWgFFtAUqBlhAsjpg.jpg
#   inflating: val/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnemmysperformancewatchnowjpg.jpg
#   inflating: val/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnstillstandingbrooklynnewyearsjpg.jpg
#   inflating: val/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnsupportsbrucejennerstransitiontowomanjpg.jpg
#   inflating: val/httpcdncdnjustjaredcomwpcontentuploadsheadlinesjerryseinfeldmakesbrianwilliamsjokejpg.jpg
#   inflating: val/httpcdncdnjustjaredcomwpcontentuploadsheadlinesmadonnatalksparisattackstearsjpg.jpg
#   inflating: val/httpcdncdnjustjaredcomwpcontentuploadsheadlinesmindykalingcomedypilotjpg.jpg
#   inflating: val/httpcdnfuncheapcomwpcontentuploadsVOGUEjpg.jpg
#   inflating: val/httpcdnlyricssongonlyricsnetwpcontentuploadsEltonJohnDiscographyCDreleasesjpg.jpg
#   inflating: val/httpcdnpastemagazinecomwwwarticlesmindykalingndbookjpg.jpg
#   inflating: val/httpcdnpastemagazinecomwwwarticlesmindyprojectjpg.jpg
#   inflating: val/httpcdnssninsidercomwpcontentuploadsjerryseinfeldxjpg.jpg
#   inflating: val/httpcsvkmeuaafdfjpg.jpg
#   inflating: val/httpcsvkmeuadecafjpg.jpg
#   inflating: val/httpdbrbzkkbdsdcloudfrontnetwpcontentuploadsMindyKalingjpg.jpg
#   inflating: val/httpecximagesamazoncomimagesIfmaBKWLACULSRjpg.jpg

# %%
# !unzip train.zip
# Out:
# Archive:  train.zip
#    creating: train/
#   inflating: train/httpcsvkmeuaeccjpg.jpg
#   inflating: train/httpftqncomymusicLxZeltonjohnjpg.jpg
#   inflating: train/httpwwwfilmscoopitcgibinattoriBENAFFLECKBENAFFLECKjpg.jpg
#   inflating: train/httpwwwhillsindcomstorebenjpg.jpg
#   inflating: train/httpwwwimpropercomimagesuploadsusercontentimagesSoroffMindyjpg.jpg
#   inflating: train/httpwwwjohnpauljonesarenacomeventimagesEltonCalendarVjpg.jpg
#   inflating: train/httpwwwlautdeEltonJohneltonjohnjpg.jpg
#   inflating: train/httpwwwnndbcompeoplejerryseinfeldaujpg.jpg
#   inflating: train/httpwwwpictureszimbiocomfpMindyKalingfBgaONVFDFmjpg.jpg
#   inflating: train/httpwwwpictureszimbiocomgiMindyKalingLkvEhTwDeJmjpg.jpg
#   inflating: train/httpwwwpictureszimbiocomgpJerrySeinfeldJessicaSeinfeldmarriedBczSipMdNMQljpg.jpg
#   inflating: train/httpwwwpsychiatrictimescomsitesdefaultfilesimagesmediaPTMofficSeinfeldjpg.jpg
#   inflating: train/httpwwwrumenewscomwpcontentuploadsbenafflekxpng.jpg
#   inflating: train/httpwwwslatecomcontentdamslateblogsbrowbeatseinfeldjpgCROParticlemediumjpg.jpg
#   inflating: train/httpwwwwatchidcomsitesdefaultfilesuploadsightingBreitlingwatchJerrySeinfeldjpg.jpg

# %%
genders = []  # list to store gender labels (0 - male, 1 - female)

with open('/content/train_csv.csv') as csv_file:  # open the CSV file for reading
    csv_reader = csv.reader(csv_file, delimiter=',')  # create CSV reader object
    line_count = 0  # line number counter

    for row in csv_reader:  # iterating over each row in the file
        if line_count == 0:
            line_count += 1  # skip the header row
        else:
            rowJson = json.loads(row[6])  # convert JSON string from 7th column to dictionary
            if rowJson["gender"] == 'male':
                genders.append(1)  # append 1 (female) to the list if the gender is male
            else:
                genders.append(0)  # append 0 (male) to the list if the gender is female
            line_count += 1

# %%
path = '/content/train'  # path to the directory with training images
x_train = []  # list to store images for training data
y_train = []  # list to store labels for training data

i = 0
for img in os.listdir(path):  # iterate over each file in the directory
    i = i + 1
    img = cv2.imread(str(path) + '/' + str(img))  # read the image file
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # convert the image to grayscale
    img = cv2.resize(img, (100, 100))  # resize the image to a fixed size
    x_train.append(np.array(img))  # append the image array to the list
    y_train.append(np.array(genders[i - 1]))  # append the corresponding label to the list

x_train = np.array(x_train)  # convert the list of image arrays to a numpy array
y_train = np.array(y_train, np.uint64)  # convert the list of labels to a numpy array of uint64 type

len(x_train)
len(y_train)
# Out:
# 90

# %%
genders = []  # list to store gender labels (0 - male, 1 - female)

with open('/content/val_csv.csv') as csv_file:  # open the CSV file for reading
    csv_reader = csv.reader(csv_file, delimiter=',')  # create CSV reader object
    line_count = 0  # line number counter

    for row in csv_reader:  # iterating over each row in the file
        if line_count == 0:
            line_count += 1  # skip the header row
        else:
            rowJson = json.loads(row[6])  # convert JSON string from 7th column to dictionary
            if rowJson["gender"] == 'male':
                genders.append(1)  # append 1 (female) to the list if the gender is male
            else:
                genders.append(0)  # append 0 (male) to the list if the gender is female
            line_count += 1

# %%
path = '/content/val'  # path to the directory with test images
x_test = []  # list to store images for test data
y_test = []  # list to store labels for test data

i = 0
for img in os.listdir(path):  # iterate over each file in the directory
    i = i + 1
    img = cv2.imread(str(path) + '/' + str(img))  # read the image file
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # convert the image to grayscale
    img = cv2.resize(img, (100, 100))  # resize the image to a fixed size
    x_test.append(np.array(img))  # append the image array to the list
    y_test.append(np.array(genders[i - 1]))  # append the corresponding label to the list

x_test = np.array(x_test)  # convert the list of image arrays to a numpy array
y_test = np.array(y_test, np.uint64)  # convert the list of labels to a numpy array of uint64 type

# %%
input = Input(shape=(100, 100, 1))  # define the input shape for the model - indicating that the input images are grayscale with dimensions 100x100

# convolutional layers (conv1, conv2, conv3, conv4 with 32, 64, 128, and 256 filters, respectively) with dropout and activation
conv1 = Conv2D(32, (3, 3), padding='same', strides=(1, 1), kernel_regularizer = l2(0.001))(input)
conv1 = Dropout(0.1)(conv1)
conv1 = Activation('relu')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), padding='same', strides=(1, 1), kernel_regularizer = l2(0.001))(pool1)
conv2 = Dropout(0.1)(conv2)
conv2 = Activation('relu')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), padding='same', strides=(1, 1), kernel_regularizer = l2(0.001))(pool2)
conv3 = Dropout(0.1)(conv3)
conv3 = Activation('relu')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), padding='same', strides=(1, 1), kernel_regularizer = l2(0.001))(pool3)
conv4 = Dropout(0.1)(conv4)
conv4 = Activation('relu')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

flatten = Flatten()(pool4)  # flatten the output of the last convolutional layer

dense_1 = Dense(128, activation='relu')(flatten)  # fully connected layer with ReLU activation

drop_1 = Dropout(0.2)(dense_1)  # dropout layer - to prevent overfitting

output = Dense(2, activation="sigmoid")(drop_1)  # output layer with sigmoid activation for binary classification - outputs

# %%
model = Model(inputs=input, outputs=output)  # create a model by specifying the input and output layers
model.compile(optimizer="adam", loss=["sparse_categorical_crossentropy"], metrics=['accuracy'])  # compile the model
model.summary()  # summary of the model architecture
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 1)]     0
#
#  conv2d (Conv2D)             (None, 100, 100, 32)      320
#
#  dropout (Dropout)           (None, 100, 100, 32)      0
#
#  activation (Activation)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  dropout_1 (Dropout)         (None, 50, 50, 64)        0
#
#  activation_1 (Activation)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  dropout_2 (Dropout)         (None, 25, 25, 128)       0
#
#  activation_2 (Activation)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  dropout_3 (Dropout)         (None, 12, 12, 256)       0
#
#  activation_3 (Activation)   (None, 12, 12, 256)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 1,567,874
# Trainable params: 1,567,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_path = './output/gender_model.h5' # path where the model will be saved
# sets the metric to monitor for saving the best model, saves only the best model based on the monitored metric, the entire model will be saved
checkpointer = ModelCheckpoint(model_path, monitor='loss', verbose=1, save_best_only=True,
                               save_weights_only=False, mode='auto', save_freq='epoch')
callback_list = [checkpointer]

# %%
save = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=30, callbacks=[callback_list])
# Out:
# Epoch 1/30
# 3/3 [==============================] - ETA: 0s - loss: 70.6949 - accuracy: 0.5889
# Epoch 1: loss improved from inf to 70.69488, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 6s 1s/step - loss: 70.6949 - accuracy: 0.5889 - val_loss: 4.5484 - val_accuracy: 0.3600
# Epoch 2/30
# 3/3 [==============================] - ETA: 0s - loss: 5.5845 - accuracy: 0.5111
# Epoch 2: loss improved from 70.69488 to 5.58451, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 5s 2s/step - loss: 5.5845 - accuracy: 0.5111 - val_loss: 2.2816 - val_accuracy: 0.4000
# Epoch 3/30
# 3/3 [==============================] - ETA: 0s - loss: 1.7898 - accuracy: 0.6333
# Epoch 3: loss improved from 5.58451 to 1.78977, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 1.7898 - accuracy: 0.6333 - val_loss: 0.9680 - val_accuracy: 0.5600
# Epoch 4/30
# 3/3 [==============================] - ETA: 0s - loss: 1.1808 - accuracy: 0.5556
# Epoch 4: loss improved from 1.78977 to 1.18080, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 1.1808 - accuracy: 0.5556 - val_loss: 0.9717 - val_accuracy: 0.6800
# Epoch 5/30
# 3/3 [==============================] - ETA: 0s - loss: 0.8644 - accuracy: 0.7000
# Epoch 5: loss improved from 1.18080 to 0.86444, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.8644 - accuracy: 0.7000 - val_loss: 1.0497 - val_accuracy: 0.4800
# Epoch 6/30
# 3/3 [==============================] - ETA: 0s - loss: 0.9132 - accuracy: 0.7222
# Epoch 6: loss did not improve from 0.86444
# 3/3 [==============================] - 6s 2s/step - loss: 0.9132 - accuracy: 0.7222 - val_loss: 1.0126 - val_accuracy: 0.5200
# Epoch 7/30
# 3/3 [==============================] - ETA: 0s - loss: 0.7318 - accuracy: 0.8444
# Epoch 7: loss improved from 0.86444 to 0.73180, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 5s 1s/step - loss: 0.7318 - accuracy: 0.8444 - val_loss: 1.0216 - val_accuracy: 0.4800
# Epoch 8/30
# 3/3 [==============================] - ETA: 0s - loss: 0.6942 - accuracy: 0.8111
# Epoch 8: loss improved from 0.73180 to 0.69423, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.6942 - accuracy: 0.8111 - val_loss: 1.0309 - val_accuracy: 0.5200
# Epoch 9/30
# 3/3 [==============================] - ETA: 0s - loss: 0.6513 - accuracy: 0.8778
# Epoch 9: loss improved from 0.69423 to 0.65127, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.6513 - accuracy: 0.8778 - val_loss: 0.9913 - val_accuracy: 0.6000
# Epoch 10/30
# 3/3 [==============================] - ETA: 0s - loss: 0.5906 - accuracy: 0.8667
# Epoch 10: loss improved from 0.65127 to 0.59061, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.5906 - accuracy: 0.8667 - val_loss: 1.0404 - val_accuracy: 0.6000
# Epoch 11/30
# 3/3 [==============================] - ETA: 0s - loss: 0.5604 - accuracy: 0.9111
# Epoch 11: loss improved from 0.59061 to 0.56042, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.5604 - accuracy: 0.9111 - val_loss: 1.0427 - val_accuracy: 0.6400
# Epoch 12/30
# 3/3 [==============================] - ETA: 0s - loss: 0.5069 - accuracy: 0.9000
# Epoch 12: loss improved from 0.56042 to 0.50688, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 5s 1s/step - loss: 0.5069 - accuracy: 0.9000 - val_loss: 1.0810 - val_accuracy: 0.6400
# Epoch 13/30
# 3/3 [==============================] - ETA: 0s - loss: 0.4409 - accuracy: 0.9556
# Epoch 13: loss improved from 0.50688 to 0.44093, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.4409 - accuracy: 0.9556 - val_loss: 1.1554 - val_accuracy: 0.6000
# Epoch 14/30
# 3/3 [==============================] - ETA: 0s - loss: 0.4276 - accuracy: 0.9778
# Epoch 14: loss improved from 0.44093 to 0.42761, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.4276 - accuracy: 0.9778 - val_loss: 1.2432 - val_accuracy: 0.5600
# Epoch 15/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3970 - accuracy: 0.9778
# Epoch 15: loss improved from 0.42761 to 0.39705, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.3970 - accuracy: 0.9778 - val_loss: 1.2478 - val_accuracy: 0.5600
# Epoch 16/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 1.0000
# Epoch 16: loss improved from 0.39705 to 0.34190, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.3419 - accuracy: 1.0000 - val_loss: 1.4739 - val_accuracy: 0.5600
# Epoch 17/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 1.0000
# Epoch 17: loss did not improve from 0.34190
# 3/3 [==============================] - 3s 1s/step - loss: 0.3446 - accuracy: 1.0000 - val_loss: 1.3463 - val_accuracy: 0.6800
# Epoch 18/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3527 - accuracy: 0.9778
# Epoch 18: loss did not improve from 0.34190
# 3/3 [==============================] - 3s 1s/step - loss: 0.3527 - accuracy: 0.9778 - val_loss: 1.2788 - val_accuracy: 0.6400
# Epoch 19/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.9889
# Epoch 19: loss improved from 0.34190 to 0.32781, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 5s 1s/step - loss: 0.3278 - accuracy: 0.9889 - val_loss: 1.2367 - val_accuracy: 0.6000
# Epoch 20/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3290 - accuracy: 0.9889
# Epoch 20: loss did not improve from 0.32781
# 3/3 [==============================] - 3s 1s/step - loss: 0.3290 - accuracy: 0.9889 - val_loss: 1.2176 - val_accuracy: 0.6400
# Epoch 21/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3116 - accuracy: 1.0000
# Epoch 21: loss improved from 0.32781 to 0.31163, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.3116 - accuracy: 1.0000 - val_loss: 1.3860 - val_accuracy: 0.6400
# Epoch 22/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3067 - accuracy: 1.0000
# Epoch 22: loss improved from 0.31163 to 0.30669, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.3067 - accuracy: 1.0000 - val_loss: 1.4289 - val_accuracy: 0.6400
# Epoch 23/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2971 - accuracy: 1.0000
# Epoch 23: loss improved from 0.30669 to 0.29705, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.2971 - accuracy: 1.0000 - val_loss: 1.4935 - val_accuracy: 0.6400
# Epoch 24/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 1.0000
# Epoch 24: loss improved from 0.29705 to 0.29366, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.2937 - accuracy: 1.0000 - val_loss: 1.5067 - val_accuracy: 0.6000
# Epoch 25/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 1.0000
# Epoch 25: loss did not improve from 0.29366
# 3/3 [==============================] - 4s 1s/step - loss: 0.2977 - accuracy: 1.0000 - val_loss: 1.5003 - val_accuracy: 0.6800
# Epoch 26/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 1.0000
# Epoch 26: loss improved from 0.29366 to 0.28819, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.2882 - accuracy: 1.0000 - val_loss: 1.4883 - val_accuracy: 0.6800
# Epoch 27/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 1.0000
# Epoch 27: loss did not improve from 0.28819
# 3/3 [==============================] - 3s 1s/step - loss: 0.2907 - accuracy: 1.0000 - val_loss: 1.5127 - val_accuracy: 0.6800
# Epoch 28/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 1.0000
# Epoch 28: loss improved from 0.28819 to 0.28681, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.2868 - accuracy: 1.0000 - val_loss: 1.5412 - val_accuracy: 0.6400
# Epoch 29/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 1.0000
# Epoch 29: loss did not improve from 0.28681
# 3/3 [==============================] - 5s 2s/step - loss: 0.2874 - accuracy: 1.0000 - val_loss: 1.5680 - val_accuracy: 0.6400
# Epoch 30/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 1.0000
# Epoch 30: loss improved from 0.28681 to 0.28388, saving model to ./output/gender_model.h5
# 3/3 [==============================] - 3s 1s/step - loss: 0.2839 - accuracy: 1.0000 - val_loss: 1.6119 - val_accuracy: 0.6800

# %%
# checking the train and test loss and accuracy values from the neural network above

train_loss = save.history['loss']
test_loss = save.history['val_loss']
train_accuracy = save.history['accuracy']
test_accuracy = save.history['val_accuracy']

# %%
# plotting a line chart to visualize the loss and accuracy values by epochs

fig, ax = plt.subplots(ncols=2, figsize=(15,7))

ax = ax.ravel()

ax[0].plot(train_loss, label='Train Loss', color='royalblue', marker='o', markersize=5)
ax[0].plot(test_loss, label='Test Loss', color = 'orangered', marker='o', markersize=5)

ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Categorical Crossentropy', fontsize=14)

ax[0].legend(fontsize=14)
ax[0].tick_params(axis='both', labelsize=12)

ax[1].plot(train_accuracy, label='Train Accuracy', color='royalblue', marker='o', markersize=5)
ax[1].plot(test_accuracy, label='Test Accuracy', color='orangered', marker='o', markersize=5)

ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)

ax[1].legend(fontsize=14)
ax[1].tick_params(axis='both', labelsize=12)

fig.suptitle(x=0.5, y=0.92, t="Lineplots showing loss and accuracy of CNN model by epochs", fontsize=16)
# Out:
# Text(0.5, 0.92, 'Lineplots showing loss and accuracy of CNN model by epochs')

# %%
# Evaluate the gender model on the test data
loss, accuracy = model.evaluate(x_test, y_test)

# Print the evaluation results
print(f'Test Loss: {loss:.2f}')
print(f'Test Accuracy: {accuracy:.2f}')
# Out:
# 1/1 [==============================] - 1s 699ms/step - loss: 1.6119 - accuracy: 0.6800
# Test Loss: 1.61
# Test Accuracy: 0.68
